# %%
from random import shuffle

from copy import deepcopy

TOTAL_TEAMS =  45

ALL_TEAMS = list(range(1,TOTAL_TEAMS))

ALL_COURTS= list(range(1, TOTAL_TEAMS, 2))

COURTS ={}
COURTS[0] = "x"
COURTS[1] = "T1"
COURTS[2] = "T2"
COURTS[3] ="T3"
COURTS[4] ="T4"
COURTS[5] ="T5"
COURTS[6] ="T6"
COURTS[7] ="T7"
COURTS[8] = "T8"
COURTS[9] = 1
COURTS[10] = 2
COURTS[11] =3
COURTS[12] =4
COURTS[13] =5
COURTS[14] =6
COURTS[15] =7
COURTS[16] =8
COURTS[17] =9
COURTS[18] =10
COURTS[19] =11
COURTS[20] =12
COURTS[21] =13
COURTS[22] =14
COURTS[23] =15
COURTS[24] =16
COURTS[25] =21
COURTS[26] =22
COURTS[27] =23
COURTS[28] =24
COURTS[29] =25
COURTS[30] =26
COURTS[31] =27
COURTS[32] =28
COURTS[33] =45
COURTS[34] =46
COURTS[35] =47
COURTS[36] =48
COURTS[37] =49
COURTS[38] =50
COURTS[39] =51
COURTS[40] =52
COURTS[41] =53
COURTS[42] =54
COURTS[43] =55
COURTS[44] =56

def make_set(ms = []):
    m = []
    teams = deepcopy(ALL_TEAMS)
    courts = deepcopy(ALL_COURTS)
   
    while teams:
        shuffle(teams)
        t1 = teams.pop()
        shuffle(teams)
        t2 = teams.pop()
        shuffle(courts)
        c1 =  courts.pop()
        g = [t1,t2,(c1, c1+1)]
        if [t1,t2] not in vs or [t2,t1] not in vs: # and g not in m  and g not in ms :
#     and ([t1,t2] not in vs and [t2,t1] not in vs ) :
#     and  [t1,(c1, c1+1)]  not in  team_crt \
#     and  [t2,(c1, c1+1)]  not in  team_crt  \
#     and  [t1,(c1+1, c1)]  not in  team_crt \
#     and  [t2,(c1+1, c1)]  not in  team_crt :

            m.append( g )

            vs.append([t1,t2])
            vs.append([t2,t1])

#             team_crt.append([t1,(c1, c1+1)])
#             team_crt.append([t2,(c1, c1+1)])
            
#             team_crt.append([t1,(c1+1, c1)])
#             team_crt.append([t2,(c1+1, c1)])

            teams = [t for t in teams if t != t1]
            teams = [t for t in teams if t != t2]
            courts= [ c for c in courts if c != c1]
            print(g)
        else:
            
            teams.append(t1)
            teams.append(t2)
            courts.append(c1)
            
            
          
            if len(teams) == 2:
                
                t1 = teams.pop()
                t2 = teams.pop()
                c1 =  courts.pop()
#                 team_crt.append([t1,(c1, c1+1)])
#                 team_crt.append([t2,(c1, c1+1)])

#                 team_crt.append([t1,(c1+1, c1)])
#                 team_crt.append([t2,(c1+1, c1)])
                
                vs.append([t1,t2])
                vs.append([t2,t1])
                
                print([t1,t2,(c1,c1+1)])
                
                m.append(  [t1,t2,(c1,c1+1)] )
                break
    return m

# %%
total = []
vs = []
team_crt = []
for x in range(1,8):

    m1 = make_set()
    total.append(m1)
    
    if len(m1) != 22:
        break
    m2  = make_set(ms = m1)
    
    if len(m2) != 22:
        break
    total.append(m2)

    m3  = make_set(ms =  m1+m2)
    
    
    if len(m3) != 22:
        break
    
    total.append(m3)
    
    print(len(m1),len(m2),len(m3))

print(len(total))
# Out:
# [18, 2, (3, 4)]
# [17, 10, (31, 32)]
# [23, 36, (23, 24)]
# [9, 15, (21, 22)]
# [3, 42, (29, 30)]
# [32, 13, (19, 20)]
# [11, 38, (9, 10)]
# [41, 44, (15, 16)]
# [35, 24, (5, 6)]
# [6, 43, (7, 8)]
# [14, 28, (25, 26)]
# [22, 16, (1, 2)]
# [27, 39, (11, 12)]
# [19, 34, (43, 44)]
# [8, 37, (27, 28)]
# [1, 25, (37, 38)]
# [5, 33, (17, 18)]
# [40, 29, (13, 14)]
# [30, 20, (33, 34)]
# [7, 31, (35, 36)]
# [12, 21, (39, 40)]
# [26, 4, (41, 42)]
# [34, 39, (19, 20)]
# [4, 15, (7, 8)]
# [38, 20, (31, 32)]
# [10, 9, (43, 44)]
# [26, 42, (29, 30)]
# [37, 28, (23, 24)]
# [16, 14, (3, 4)]
# [36, 7, (13, 14)]
# [44, 6, (11, 12)]
# [19, 41, (21, 22)]
# [23, 17, (37, 38)]
# [35, 22, (9, 10)]
# [12, 13, (33, 34)]
# [2, 29, (25, 26)]
# [1, 30, (35, 36)]
# [5, 31, (15, 16)]
# [24, 43, (27, 28)]
# [21, 25, (39, 40)]
# [8, 33, (41, 42)]
# [40, 18, (1, 2)]
# [32, 27, (17, 18)]
# [3, 11, (5, 6)]
# [9, 29, (9, 10)]
# [7, 4, (29, 30)]
# [5, 35, (27, 28)]
# [32, 16, (11, 12)]
# [1, 27, (23, 24)]
# ...

# %%
# from itertools import zip

wks = []

t = total[0:3]
for t in zip(*[iter(total)]*3):
    l = {}
    for team in list(range(1,TOTAL_TEAMS)):
    #         print(team)
        l[team] = []
        for g in t:
            assert len(g) == 22
            for match in g:
                if team in match:
                    l[team].append(match)
    wks.append(l)
                    
def court(x):
    for g in x:
        if(type(g) is tuple):
         court = g
    return court
                
x = ""    
y = 0
with open('games_formatted_mon_2.csv', 'w') as file:
        file.write("Week,Team#,Match1,Match2,Match3\n")
        print("Week,Team#,Match1,Match2,Match3\n")
        for y in [0,1,2,3,4,5,6]:
            t = wks[y]
            for k in t.keys():
                try:
                    
                    msg = f"{y+1}, {k:<5}, {COURTS[court(t[k][0])[0]]}&{COURTS[court(t[k][0])[1]]} , {COURTS[court(t[k][1])[0]]}&{COURTS[court(t[k][1])[1]]} , {COURTS[court(t[k][2])[0]]}&{COURTS[court(t[k][2])[1]]} "
#                     print(msg)
                    file.write(f"{msg} \n")
                except Exception as err:
                    print("!!!!! "+err, t[k])
# Out:
# Week,Team#,Match1,Match2,Match3

# %%
import pandas as pd

vsc = {}

df = pd.read_csv("games_formatted_mon_2.csv")
for row in df.iterrows():
    r = row[1]
    for row1 in df.iterrows():
        
        r1 = row1[1]
        if r.Week == r1.Week and (r.Match1 == r1.Match1 or r.Match2 == r1.Match2 or r.Match3 == r1.Match3):
            if r['Team#'] != r1['Team#']:
#                 print(f"WK{r.Week} A{r['Team#']} B{r1['Team#']}")
                if r['Team#'] in vsc:
                     vsc[r['Team#']].append(r1['Team#'])
                else:
                    vsc[r['Team#']] = [r1['Team#']]
                    
for v in vsc:
    print(v, len(set( vsc[v]))  , vsc[v]   )
# Out:
# 1 21 [25, 27, 30, 6, 9, 24, 15, 23, 43, 13, 20, 34, 7, 21, 33, 11, 28, 39, 2, 31, 35]
# 2 21 [18, 29, 37, 23, 32, 42, 9, 16, 34, 4, 7, 14, 5, 31, 39, 13, 38, 41, 1, 20, 36]
# 3 21 [11, 34, 42, 38, 39, 41, 4, 15, 28, 10, 27, 35, 8, 31, 40, 13, 29, 30, 18, 23, 32]
# 4 21 [7, 15, 26, 22, 23, 38, 3, 28, 39, 2, 17, 40, 8, 11, 27, 12, 18, 29, 24, 34, 43]
# 5 21 [31, 33, 35, 7, 34, 37, 10, 19, 24, 16, 17, 25, 2, 28, 36, 6, 26, 40, 9, 20, 41]
# 6 21 [11, 43, 44, 1, 7, 40, 18, 37, 39, 8, 27, 36, 14, 34, 35, 5, 30, 33, 15, 21, 32]
# 7 21 [4, 31, 36, 5, 6, 10, 30, 42, 44, 2, 18, 23, 1, 12, 20, 25, 27, 43, 14, 17, 39]
# 8 21 [21, 33, 37, 9, 18, 44, 25, 29, 38, 6, 15, 39, 3, 4, 27, 20, 28, 31, 11, 14, 19]
# 9 21 [10, 15, 29, 1, 8, 20, 2, 33, 35, 21, 27, 32, 13, 38, 40, 12, 25, 42, 5, 11, 44]
# 10 21 [9, 12, 17, 7, 19, 25, 5, 22, 26, 3, 11, 24, 16, 34, 43, 23, 33, 35, 13, 27, 28]
# 11 21 [3, 6, 38, 28, 33, 35, 14, 17, 42, 10, 12, 32, 4, 22, 30, 1, 37, 43, 8, 9, 25]
# ...
